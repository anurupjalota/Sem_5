# %% [markdown]
# # **Part 1 of Lab-01**

# %% [markdown]
# ## **Tabular Data Processing**

# %% [markdown]
# import libraries and read data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('wine.data', names=['class', 'Alcohol','Malic acid','Ash','Alcalinity of ash', 
 	 'Magnesium',
	 'Total phenols',
 	 'Flavanoids',
 	 'Nonflavanoid phenols',
 	 'Proanthocyanins',
	'Color intensity',
 	'Hue',
 	'OD280/OD315 of diluted wines',
   'Proline'])

# %% [markdown]
# Matrix Details

# %%
print("size = ",data.size)
print("shape = ",data.shape)
print("Rows = ",len(data))
print("Columns = ",len(data.columns))
# Out:
# size =  2492
# shape =  (178, 14)
# Rows =  178
# Columns =  14

# %% [markdown]
# Original Data

# %%
print("Original Data: ",data)
# Out:
# Original Data:       class  Alcohol  Malic acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0        1    14.23        1.71  ...  1.04                          3.92     1065
# 1        1    13.20        1.78  ...  1.05                          3.40     1050
# 2        1    13.16        2.36  ...  1.03                          3.17     1185
# 3        1    14.37        1.95  ...  0.86                          3.45     1480
# 4        1    13.24        2.59  ...  1.04                          2.93      735
# ..     ...      ...         ...  ...   ...                           ...      ...
# 173      3    13.71        5.65  ...  0.64                          1.74      740
# 174      3    13.40        3.91  ...  0.70                          1.56      750
# 175      3    13.27        4.28  ...  0.59                          1.56      835
# 176      3    13.17        2.59  ...  0.60                          1.62      840
# ...

# %% [markdown]
# Transpose Data

# %%
print("Transpose: ",data.transpose())
# Out:
# Transpose:                                    0        1        2    ...     175     176     177
# class                            1.00     1.00     1.00  ...    3.00    3.00    3.00
# Alcohol                         14.23    13.20    13.16  ...   13.27   13.17   14.13
# Malic acid                       1.71     1.78     2.36  ...    4.28    2.59    4.10
# Ash                              2.43     2.14     2.67  ...    2.26    2.37    2.74
# Alcalinity of ash               15.60    11.20    18.60  ...   20.00   20.00   24.50
# Magnesium                      127.00   100.00   101.00  ...  120.00  120.00   96.00
# Total phenols                    2.80     2.65     2.80  ...    1.59    1.65    2.05
# Flavanoids                       3.06     2.76     3.24  ...    0.69    0.68    0.76
# Nonflavanoid phenols             0.28     0.26     0.30  ...    0.43    0.53    0.56
# Proanthocyanins                  2.29     1.28     2.81  ...    1.35    1.46    1.35
# ...

# %% [markdown]
# Inverse

# %%
print("Inverse: ",np.linalg.pinv(data))
# Out:
# Inverse:  [[-4.54419093e-03  1.97743383e-02 -2.53172747e-04 ...  4.65721685e-03
#    1.14668342e-02 -2.99274268e-02]
#  [-1.91403192e-03 -9.46930704e-04 -3.82950722e-03 ... -8.38414213e-03
#   -6.35726820e-03  4.53721038e-03]
#  [-3.08808072e-03  6.59423828e-04  2.05567026e-03 ...  9.04901116e-03
#   -4.99746714e-03  2.50847071e-03]
#  ...
#  [-3.15542387e-02 -7.58443150e-03 -1.12894728e-04 ...  2.06454863e-02
#   -2.92694920e-02 -6.20962989e-03]
#  [ 3.14342304e-02  2.31059282e-02 -1.60538327e-03 ...  1.16920945e-02
#    1.30087689e-02 -1.31715554e-02]
#  [-1.40969633e-05  1.37135436e-05  2.72291537e-05 ...  1.25659704e-05
#    2.22853630e-05 -4.35155401e-05]]

# %% [markdown]
# DOT Product

# %%
print(data.dot(data.transpose()))
# Out:
#               0             1    ...           176          177
# 0    1.150880e+06  1.131380e+06  ...  9.104222e+05  609262.0474
# 1    1.131380e+06  1.112857e+06  ...  8.944657e+05  598132.8578
# 2    1.275411e+06  1.254800e+06  ...  1.008150e+06  674027.7628
# 3    1.591113e+06  1.565757e+06  ...  1.257390e+06  840371.9200
# 4    7.983467e+05  7.840190e+05  ...  6.322257e+05  423706.5902
# ..            ...           ...  ...           ...          ...
# 173  8.007586e+05  7.869768e+05  ...  6.336998e+05  424334.4945
# 174  8.123279e+05  7.981965e+05  ...  6.429781e+05  430653.1555
# 175  9.051057e+05  8.892232e+05  ...  7.165032e+05  479932.7886
# 176  9.104222e+05  8.944657e+05  ...  7.206898e+05  482716.8900
# 177  6.092620e+05  5.981329e+05  ...  4.827169e+05  323743.7128
#
# [178 rows x 178 columns]

# %% [markdown]
# LINE GRAPH

# %%
data[['Alcohol','Ash']].plot.line(title="Wine dataset", figsize=(7,7))

# %% [markdown]
# BAR Graph

# %%
dat = data.iloc[2:6]
dat[['Ash','Malic acid']].plot.bar()

# %% [markdown]
# HISTOGRAM

# %%
data[["Ash"]].plot.hist()

# %% [markdown]
# SCATTER PLOT

# %%
data.plot.scatter(x="Ash",y="Alcohol")

# %% [markdown]
# PIE Chart

# %%
data.transpose()[0].drop(["Proline"], axis=0).plot.pie(y=0,figsize=(8,8))

# %% [markdown]
# Reading .csv files

# %%
data = pd.read_csv("Placement_Data_Full_Class.csv")
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0      1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1      2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2      3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3      4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4      5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 15 columns]

# %% [markdown]
# Reading .tsv files

# %%
data = pd.read_csv("custdata2.tsv", sep="\t")
data.head()
# Out:
#    custid sex is.employed  income  ... recent.move  num.vehicles age state.of.res
# 0    2068   F         NaN   11300  ...       False           2.0  49     Michigan
# 1    2848   M        True    4500  ...        True           3.0  22      Georgia
# 2    5641   M        True   20000  ...       False           0.0  22   New Mexico
# 3    6369   F        True   12000  ...        True           1.0  31      Florida
# 4    8322   F        True  180000  ...       False           1.0  40     New York
#
# [5 rows x 11 columns]

# %% [markdown]
# Reading .arff files

# %%
from scipy.io import arff
data = arff.loadarff('weather.arff')
df = pd.DataFrame(data[0])

df.head()
# Out:
#        outlook  temperature  humidity     windy    play
# 0     b'sunny'         85.0      85.0  b'FALSE'   b'no'
# 1     b'sunny'         80.0      90.0   b'TRUE'   b'no'
# 2  b'overcast'         83.0      86.0  b'FALSE'  b'yes'
# 3     b'rainy'         70.0      96.0  b'FALSE'  b'yes'
# 4     b'rainy'         68.0      80.0  b'FALSE'  b'yes'

# %% [markdown]
# Reading .xlsx files

# %%
data = pd.read_excel("c_bank.xlsx")
data.head()
# Out:
#         date  dual_currency_basket  ...  foreign_exchange_reserves  monetary_gold
# 0 2012-01-11               35.8717  ...                    453 952         44 697
# 1 2012-01-12               35.6115  ...                    453 952         44 697
# 2 2012-01-13               35.5527  ...                    453 952         44 697
# 3 2012-01-14               35.6492  ...                    453 952         44 697
# 4 2012-01-17               35.7368  ...                    453 952         44 697
#
# [5 rows x 20 columns]

# %% [markdown]
# Reading .ods files

# %%
# pip install odfpy
pd.read_excel("Football-UEFA U17 Championship 2019.ods", engine="odf")
# Out:
#      time day   date  year  ... Goalkeeper Saves Fouls Yellow Cards Red Cards
# 0   19h00  Mo  05-13  2019  ...                4    13            3         0
# 1   19h00  Mo  05-13  2019  ...                6    18            3         0
# 2   16h30  Mo  05-16  2019  ...                2    24            4         0
# 3   16h30  Mo  05-16  2019  ...                3    19            3         0
# 4   19h00  Mo  05-16  2019  ...                0     7            0         0
# ..    ...  ..    ...   ...  ...              ...   ...          ...       ...
# 62  14h00  Sa  05-04  2019  ...                0    21            0         0
# 63  19h00  Fr  05-03  2019  ...                2    19            4         0
# 64  19h00  Fr  05-03  2019  ...                0    13            2         0
# 65  12h00  Fr  05-03  2019  ...                1    20            3         0
# 66  12h00  Fr  05-03  2019  ...                1    18            5         1
#
# [67 rows x 29 columns]

# %% [markdown]
# # **Part 2 of Lab-01**

# %% [markdown]
# ## **Image**

# %% [markdown]
# installing libraries

# %%
#pip install matplotlib
#pip install opencv-python
# pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 35.5MB 1.2MB/s
# ...

# %% [markdown]
# Read using matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('img0.jpg')
plt.imshow(img)

# %% [markdown]
# Read using PIL

# %%
from PIL import Image   
Image.open(r"img2.bmp")
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=523x470 at 0x7F19BA855278>

# %% [markdown]
# Read using Opencv

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('img1.png',-1)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGBA size=400x600 at 0x7F19BA8B6F28>

# %% [markdown]
# Reading .tiff image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('img3.tiff')
plt.imshow(img)

# %% [markdown]
# Properties of image

# %%
image = cv2.imread('img0.jpg',-1)
height = image.shape[0]
width = image.shape[1]
channels = image.shape[2]


print('Image Height       : ',height)
print('Image Width        : ',width)
print('Number of Channels : ',channels)
# Out:
# Image Height       :  400
# Image Width        :  600
# Number of Channels :  3

# %% [markdown]
# Conversion to greyscale

# %%
img3 = cv2.imread('img3.tiff',0)
cv2_imshow(img3)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7F19AF368400>

# %% [markdown]
# Conversion to binary

# %%
img3 = cv2.imread('img3.tiff',-1)
ret, bw_img = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
cv2_imshow(bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGBA size=600x400 at 0x7F19AF3688D0>

# %% [markdown]
# Image cropping

# %%
img = cv2.imread("img3.tiff",-1)
crop_img = img[70:200, 240:600].copy()
cv2_imshow(crop_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGBA size=360x130 at 0x7F19AF368898>

# %% [markdown]
# Rescaling

# %%
src = cv2.imread("img3.tiff",-1)
scale_percent = 50

width = int(src.shape[1] * scale_percent / 100)
height = int(src.shape[0] * scale_percent / 100)
dsize = (width, height)
output = cv2.resize(src, dsize)
cv2_imshow(output)
cv2.waitKey(0)
cv2.destroyAllWindows()
print("Original Dimensions: ",img.shape)
print("Rescaled Dimensions: ",output.shape)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x200 at 0x7F19AF364CF8>
# Original Dimensions:  (400, 600, 4)
# Rescaled Dimensions:  (200, 300, 4)

# %% [markdown]
# DICOM images

# %%
import matplotlib.pyplot as plt
import pydicom
# from pydicom.data import get_testdata_files

# print(__doc__)

# filename = get_testdata_files('CT_small.dcm')[0]
dataset = pydicom.dcmread('img4.dcm')

pat_name = dataset.PatientName
display_name = pat_name.family_name + ", " + pat_name.given_name
print("Patient's name...:", display_name)
print("Patient id.......:", dataset.PatientID)
print("Modality.........:", dataset.Modality)
# print("Study Date.......:", dataset.StudyDate)

if 'PixelData' in dataset:
    rows = int(dataset.Rows)
    cols = int(dataset.Columns)
    print("Image size.......: {rows:d} x {cols:d}, {size:d} bytes".format(
        rows=rows, cols=cols, size=len(dataset.PixelData)))
    if 'PixelSpacing' in dataset:
        print("Pixel spacing....:", dataset.PixelSpacing)

# use .get() if not sure the item exists, and want a default value if missing
print("Slice location...:", dataset.get('SliceLocation', "(missing)"))

# plot the image using matplotlib
plt.imshow(dataset.pixel_array, cmap=plt.cm.bone)
plt.show()
# Out:
# Patient's name...: Anonymized,
# Patient id.......: 0
# Modality.........: OT
# Image size.......: 512 x 512, 262144 bytes
# Slice location...: (missing)

# %% [markdown]
# ## **Video**

# %% [markdown]
# read .mp4 files

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture('vid1.mp4') 

if (cap.isOpened()== False): 
  print("Error opening video file") 
while(cap.isOpened()):  
  ret, frame = cap.read() 
  if ret == True: 
    cv2_imshow(frame) 
    if cv2.waitKey(25) & 0xFF == ord('q'): 
      break
  else: 
    break
  
cap.release() 
cv2.destroyAllWindows()

# %% [markdown]
# Read .avi files

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture('vid0.avi') 

if (cap.isOpened()== False): 
  print("Error opening video file") 
while(cap.isOpened()):  
  ret, frame = cap.read() 
  if ret == True: 
    cv2_imshow(frame) 
    if cv2.waitKey(25) & 0xFF == ord('q'): 
      break
  else: 
    break
  
cap.release() 
cv2.destroyAllWindows()

# %% [markdown]
# Read .mpg files

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture('vid2.mpg') 

if (cap.isOpened()== False): 
  print("Error opening video file") 
while(cap.isOpened()):  
  ret, frame = cap.read() 
  if ret == True: 
    cv2_imshow(frame) 
    if cv2.waitKey(25) & 0xFF == ord('q'): 
      break
  else: 
    break
  
cap.release() 
cv2.destroyAllWindows()

# %% [markdown]
# Properties of video

# %%
import cv2

vid = cv2.VideoCapture("vid0.avi")
print("Frame Rate: ",int(vid.get(cv2.CAP_PROP_FPS)))
print("Frame Height: ",int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT)))
print("Frame Width: ",int(vid.get(cv2.CAP_PROP_FRAME_WIDTH)))
print("Total number of frames: ",int(vid.get(cv2.CAP_PROP_FRAME_COUNT)))
# Out:
# Frame Rate:  30
# Frame Height:  240
# Frame Width:  256
# Total number of frames:  182

# %% [markdown]
# Video to Frames

# %%
import cv2
vidcap = cv2.VideoCapture('vid0.avi')
def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        cv2.imwrite("./images/image"+str(count)+".jpg", image)     # save frame as JPG file
    return hasFrames
sec = 0
frameRate = 30 #//it will capture image in each 0.5 second
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

# %% [markdown]
# Frames to video

# %%
import cv2
import numpy as np
import os
from os.path import isfile, join
pathIn= './images/'
pathOut = 'video.avi'
fps = 30
frame_array = []
files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
#for sorting the file names properly
files.sort(key = lambda x: x[5:-4])
files.sort()
frame_array = []
files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
#for sorting the file names properly
files.sort(key = lambda x: x[5:-4])
for i in range(len(files)):
    filename=pathIn + files[i]
    #reading each files
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    
    #inserting the frames into an image array
    frame_array.append(img)
out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
for i in range(len(frame_array)):
    # writing to a image array
    out.write(frame_array[i])
out.release()

# %% [markdown]
# ## **Audio**

# %%
from playsound import playsound
playsound('audio0.mp3')

# %% [markdown]
# AUDIO VISUALISATION

# %%
import IPython.display as ipd
ipd.Audio("audio0.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Spectrogram

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

filename1 = 'audio2.wav'
plt.figure(figsize=(15,4))
data1,sample_rate1 = librosa.load(filename1, sr=22050, mono=True, offset=0.0, duration=50, res_type='kaiser_best')
librosa.display.waveplot(data1,sr=sample_rate1, max_points=50000.0, x_axis='time', offset=0.0, max_sr=1000)

# %% [markdown]
# Properties of Audio file

# %%
print("Sample rate = ", sample_rate1)
print("Duration = ",librosa.get_duration(filename='audio2.wav'))
# Out:
# Sample rate =  22050
# Duration =  3.108730158730159

# %% [markdown]
# MFCC

# %%
y, sr = librosa.load("audio2.wav")
mfcc=librosa.feature.mfcc(y=y, sr=sr)
print(mfcc)
# Out:
# [[-1.86322996e+01 -3.92538712e+01 -8.55025791e+01 ... -2.78440102e+02
#   -3.20003400e+02 -2.63507745e+02]
#  [ 9.35372617e+01  8.52858621e+01  6.77556803e+01 ...  1.32549845e+02
#    1.24345759e+02  1.24286410e+02]
#  [ 1.48223811e+01  2.33144803e+01  3.26820268e+01 ...  2.89488083e+01
#    3.07566459e+01  2.68016663e+00]
#  ...
#  [ 2.35202441e+00  5.02874942e+00  3.84784749e+00 ...  1.32746630e+00
#    3.29185652e+00  1.79819776e-01]
#  [-7.03464431e+00 -4.57292068e+00 -2.09087959e+00 ... -1.04940539e+00
#    3.36410193e-01 -3.32922220e+00]
#  [ 2.03792762e-01  4.75158474e+00  7.45645257e+00 ...  2.03983978e+00
#    5.72160515e+00  4.42969247e+00]]

# %% [markdown]
# Visualize **MFCC**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
librosa.display.specshow(mfcc, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()

# %% [markdown]
# STFT

# %%
y, sr = librosa.load("audio2.wav")
D = librosa.stft(y)
import matplotlib.pyplot as plt
librosa.display.specshow(librosa.amplitude_to_db(D,ref=np.max),y_axis='log', x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.6/dist-packages/librosa/core/spectrum.py:983: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn('amplitude_to_db was called on complex input so phase '

# %% [markdown]
# ## **Text**

# %% [markdown]
# Read txt

# %%
f = open("sample.txt", "r")
print(f.read())
# Out:
# I would love to try or hear the sample audio your app can produce. I do not want to purchase, because I've purchased so many apps that say they do something and do not deliver.
#
# Can you please add audio samples with text you've converted? I'd love to see the end results.
#
# Thanks!

# %% [markdown]
# Read PDF

# %%
# pip install pypdf2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.3MB/s
# ...
#   Created wheel for pypdf2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=926ce321f8e7a688b95251bd2c8d1ed37a330576890b9112375cde10de121f90
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built pypdf2
# ...

# %%
import PyPDF2 
  

pdfFileObj = open('sample.pdf', 'rb') 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 

print(pdfReader.numPages) 
pageObj = pdfReader.getPage(0) 
print(pageObj.extractText()) 
pdfFileObj.close()
# Out:
# 2
#  A Simple PDF File  This is a small demonstration .pdf file -  just for use in the Virtual Mechanics tutorials. More text. And more  text. And more text. And more text. And more text.  And more text. And more text. And more text. And more text. And more  text. And more text. Boring, zzzzz. And more text. And more text. And  more text. And more text. And more text. And more text. And more text.  And more text. And more text.  And more text. And more text. And more text. And more text. And more  text. And more text. And more text. Even more. Continued on page 2 ...

# %% [markdown]
# Reading .json files

# %%
import json

f = open('sample.json') 
data = json.load(f) 
print(data)

f.close()
# Out:
# {'quiz': {'sport': {'q1': {'question': 'Which one is correct team name in NBA?', 'options': ['New York Bulls', 'Los Angeles Kings', 'Golden State Warriros', 'Huston Rocket'], 'answer': 'Huston Rocket'}}, 'maths': {'q1': {'question': '5 + 7 = ?', 'options': ['10', '11', '12', '13'], 'answer': '12'}, 'q2': {'question': '12 - 8 = ?', 'options': ['1', '2', '3', '4'], 'answer': '4'}}}}

# %% [markdown]
# Reading .html files

# %%
import codecs

f=codecs.open("sample.html", 'r')
print (f.read())
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>My First Heading</h1>
#
# <p>My first paragraph.</p>
#
# </body>
# </html>

# %% [markdown]
# Reading .xml files

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('sample.xml')
root = tree.getroot()
print("Tags = ")
print(i.tag)
print()
for i in root:
    print("Attriutes = ")
    print(i.attrib)
    print()
# Out:
# Tags =
# book
#
# Attriutes =
# {'id': 'bk101'}
#
# Attriutes =
# {'id': 'bk102'}
#
# Attriutes =
# {'id': 'bk103'}
#
# Attriutes =
# {'id': 'bk104'}
#
# Attriutes =
# {'id': 'bk105'}
#
# Attriutes =
# {'id': 'bk106'}
#
# Attriutes =
# {'id': 'bk107'}
#
# Attriutes =
# {'id': 'bk108'}
#
# Attriutes =
# {'id': 'bk109'}
#
# Attriutes =
# {'id': 'bk110'}
#
# Attriutes =
# {'id': 'bk111'}
#
# Attriutes =
# {'id': 'bk112'}

# %% [markdown]
# Word cloud

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 


df = pd.read_csv(r"Youtube02-KatyPerry.csv", encoding ="latin-1") 

comment_words = '' 
stopwords = set(STOPWORDS) 

# iterate through the csv file 
for val in df.CONTENT: 
	
	# typecaste each val to string 
	val = str(val) 

	# split the value 
	tokens = val.split() 
	
	# Converts each token into lowercase 
	for i in range(len(tokens)): 
		tokens[i] = tokens[i].lower() 
	
	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800, 
				background_color ='white', 
				stopwords = stopwords, 
				min_font_size = 10).generate(comment_words) 

# plot the WordCloud image					 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()
